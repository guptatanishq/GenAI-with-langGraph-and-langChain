# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.tools import tool

# %%
@tool
def add_number(a:int , b:int):
    """
        it will add the two numbers 
        Args:
            a : Number one
            b : Number twp


    """
    return a+b

@tool
def sub_number(a:int , b:int):
    """
        it will subtract the two numbers 
        Args:
            a : Number one
            b : Number twp


    """
    return a-b

# %%
add_number.invoke({"a": 12, "b": 3})
sub_number.invoke({"a": 12, "b": 3})
# Out:
# 9

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.agents import create_agent

# %%
llm = ChatGoogleGenerativeAI(model = 'gemini-3.5-flash-lite')

# %%
agent = create_agent(
    model = llm,
    tools = [add_number, sub_number],
    system_prompt = "you are a math teacher and uses tool for calculation"
    
)

# %%
res = agent.invoke({"messages": [{"role":"user", "content": "what is 2+30-10"}]})

# %%
final_message = res['messages'][-1]
print(final_message.content[0]['text'])
# Out:
# The result of 2 + 30 - 10 is 22.
#
# Here are the steps I took:
# 1. First, I added 2 and 30, which equals 32.
# 2. Then, I subtracted 10 from 32, which gives us 22.

# %%
for res in res['messages']:
    print(res)
    print('\n')
# Out:
# content='what is 2+3' additional_kwargs={} response_metadata={} id='3b9afebf-0963-45c6-8be6-15d693ab7d4e'
#
#
# content=[] additional_kwargs={'function_call': {'name': 'add_number', 'arguments': '{"b": 3, "a": 2}'}, '__gemini_function_call_thought_signatures__': {'LPIrUSio': 'EjQKMgERTTIPbaW0O9CvLDAEoKYHToMfIbx6DXZRuq9Feu6nptH0AtL+adVlfbuBNV075iJg'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019fc737-2784-7df2-99d2-5f2c7a76ddae-0' tool_calls=[{'name': 'add_number', 'args': {'b': 3, 'a': 2}, 'id': 'LPIrUSio', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 161, 'output_tokens': 18, 'total_tokens': 179, 'input_token_details': {'cache_read': 0}}
#
#
# content='5' name='add_number' id='9aefbf1c-3364-4613-a8f9-08a66aed4825' tool_call_id='LPIrUSio'
#
#
# ...
