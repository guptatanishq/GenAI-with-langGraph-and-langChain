# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model = "gemini-3.5-flash-lite", streaming=True)

# %%
question = "tell me about the genai"

# %%
res = llm.stream(question)
for chunk in res:
    print(chunk.text,end = "")
# Out:
# **Generative AI (GenAI)** is a type of artificial intelligence that can create new content—including text, images, audio, video, code, and 3D models—based on the data it has been trained on.
#
# Unlike traditional AI, which is designed to analyze data, recognize patterns, or make predictions (like recommending a movie on Netflix or flagging spam emails), **GenAI actually creates something new.**
#
# Here is a comprehensive breakdown of GenAI, how it works, its popular tools, and its impact on the world.
#
# ---
#
# ### 1. How Does It Work?
# At its core, GenAI relies on **Machine Learning**, specifically deep learning models trained on massive amounts of data.
# * **Training Data:** A GenAI model (like the ones powering ChatGPT or Midjourney) is fed billions of examples—books, articles, websites, paintings, or music.
# ...

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model = 'openai/gpt-oss-20b',stream = True)

# %%
question = 'explain genai'

# %%
res = llm.stream(question)
for chunk in res:
    print(chunk.content, end="")
# Out:
# ## What is “GenAI” (Generative AI)?
#
# Generative AI refers to a class of artificial‑intelligence models that can **create** new content—text, images, audio, video, code, and more—rather than just analyze or classify existing data. Unlike traditional AI that merely recognizes patterns, generative models learn a statistical representation of a dataset and then use that representation to produce novel samples that look (or feel) similar to the training data.
#
# ---
#
# ### Core Technologies
#
# | Layer | Key Idea | Typical Models |
# |-------|----------|----------------|
# | **Data Collection** | Gather large, diverse datasets (e.g., books, web pages, images). | Web‑scraped corpora, ImageNet, COCO, etc. |
# | **Representation Learning** | Encode raw data into high‑dimensional vectors. | Transformers, CNNs, VAEs, diffusion encoders. |
# | **Generation Engine** | Sample or decode from the learned distribution. | GPT‑style transformers, Stable Diffusion, DALL‑E, WaveNet, LLMs. |
# ...
