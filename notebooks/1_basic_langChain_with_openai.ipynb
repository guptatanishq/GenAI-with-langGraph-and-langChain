# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model = "gemini-3.5-flash-lite" )

# %%
res = llm.invoke("what is genai")
print(res.content)
# Out:
# [{'type': 'text', 'text': "**GenAI** is short for **Generative Artificial Intelligence**. \n\nIt is a type of artificial intelligence technology that can create **new content**, such as text, images, audio, video, code, and 3D models, in response to user prompts or requests.\n\nUnlike traditional AI—which is designed to analyze data, recognize patterns, or make predictions (like recommending a movie on Netflix or filtering spam emails)—GenAI is designed to **create**.\n\nHere is a breakdown to help you understand it better:\n\n### 1. How It Works\nGenAI is powered by massive machine learning models, specifically a type called **Foundation Models** (such as Large Language Models like GPT-4). \n* These models are trained on vast amounts of data (like books, websites, art, and music) using the internet.\n* When you give it a **prompt** (a question or instruction), the AI uses probability to predict and generate the most likely and relevant response, word-by-word or pixel-by-pixel.\n\n### 2. Popular Examples of GenAI\nYou have likely already interacted with GenAI. Some of the most popular tools include:\n* **Text/Chatbots:** ChatGPT (OpenAI), Claude (Anthropic), Gemini (Google), and Microsoft Copilot. These can write essays, summarize documents, write computer code, and hold conversations.\n* **Image Generation:** Midjourney, DALL-E 3, and Stable Diffusion. These create realistic photos, paintings, or illustrations from a text description.\n* **Video Generation:** Sora (OpenAI) and Runway. These generate short, high-definition videos from text prompts.\n* **Audio/Music Generation:** ElevenLabs (for realistic voice cloning and text-to-speech) and Suno (for creating full songs).\n\n### 3. Why is GenAI a Big Deal?\nGenAI represents a major shift in how humans interact with computers. \n* **Accessibility:** You don't need to know how to code or use complex software to create; you just need to be able to talk or type in plain English (or your native language).\n* **Productivity:** It automates repetitive tasks like drafting emails, summarizing meetings, and debugging code.\n* **Creativity:** It acts as a brainstorming partner, helping artists, writers, and designers overcome creative blocks.\n\n### 4. Challenges and Risks\nWhile powerful, GenAI also comes with significant challenges:\n* **Hallucinations:** GenAI tools sometimes invent false information and present it as absolute fact.\n* **Copyright and Ethics:** Models are trained on existing human art and writing, leading to debates and lawsuits over intellectual property.\n* **Deepfakes and Misuse:** It can be used to create hyper-realistic fake videos, scam people, or spread misinformation quickly. \n\nIn short, **GenAI is a digital creator.** It takes human input and instantly generates original-looking output, changing how we work, learn, and create.", 'extras': {'signature': 'EjQKMgERTTIP/Oafk8xkIn/BFklqgQZOv9YfQPNYFBEunxU3s3fnja9K3PIkSWvz+vzxpgvu'}}]

# %% [markdown]
# #### Static prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model = "gemini-3.5-flash-lite" )

# %%
prompts = [
    ("system", "you are a python developer"), ###(type, ) "system", "ai", 
    ("user", "how to sort the array")
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# [{'type': 'text', 'text': 'Sorting an array (which Python usually calls a **list**) is very straightforward in Python. \n\nHere are the most common ways to do it, depending on your needs:\n\n### 1. Using the `sort()` method (Modifies the original list)\nIf you want to sort the existing list in-place and don\'t mind changing the original order, use the `.sort()` method.\n\n```python\nnumbers = [5, 2, 9, 1, 5, 6]\n\n# Sort in ascending order (default)\nnumbers.sort()\nprint(numbers)  # Output: [1, 2, 5, 5, 6, 9]\n\n# Sort in descending order\nnumbers.sort(reverse=True)\nprint(numbers)  # Output: [9, 6, 5, 5, 2, 1]\n```\n\n### 2. Using the `sorted()` function (Creates a new list)\nIf you want to keep the original list unchanged and create a *new* sorted list, use the `sorted()` function.\n\n```python\nnumbers = [5, 2, 9, 1, 5, 6]\n\n# Returns a new sorted list\nsorted_numbers = sorted(numbers)\n\nprint(sorted_numbers)  # Output: [1, 2, 5, 5, 6, 9]\nprint(numbers)         # Output: [5, 2, 9, 1, 5, 6] (remains unchanged)\n```\n\n---\n\n### Advanced Sorting\n\n#### Sorting strings (Alphabetically)\n```python\nnames = ["Charlie", "Alice", "Bob"]\nnames.sort()\nprint(names)  # Output: [\'Alice\', \'Bob\', \'Charlie\']\n```\n\n#### Sorting by length (using the `key` parameter)\nYou can customize how Python compares items by passing a function to the `key` argument.\n```python\nwords = ["apple", "pie", "banana", "cat"]\n\n# Sort words by their length\nwords.sort(key=len)\nprint(words)  # Output: [\'pie\', \'cat\', \'apple\', \'banana\']\n```\n\n---\n\n### What if you are using NumPy or Pandas?\nIf you are working with data science arrays (NumPy arrays), the syntax is slightly different:\n\n```python\nimport numpy as np\n\narr = np.array([5, 2, 9, 1])\n\n# Using numpy\'s sort function (returns a sorted copy)\nsorted_arr = np.sort(arr)\nprint(sorted_arr)  # Output: [1 2 5 9]\n```', 'extras': {'signature': 'EjQKMgERTTIPwjkzR23QgUcVu8LcHX/SJNFWrGXfz0ske7u8/kuJRyhVWDDFUGmA3niHb7rd'}}]
